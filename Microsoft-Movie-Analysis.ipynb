# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
title_basics_data = pd.read_csv("C:/Users/AnnieLiu/Desktop/Misc/DA - Materials/Project 1/title.basics.csv")

# %% [markdown]
# # Understanding the data from "title.basics.csv"

# %%
title_basics_data.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
title_basics_data.tail()
# Out:
#            tconst                                primary_title  \
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes       genres
# 146139            123.0        Drama
# 146140              NaN  Documentary
# 146141              NaN       Comedy
# 146142            116.0          NaN
# 146143              NaN  Documentary

# %%
title_basics_data.shape
# Out:
# (146144, 6)

# %%
title_basics_data.columns
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres'],
#       dtype='object')

# %%
title_ratings_data = pd.read_csv("C:/Users/AnnieLiu/Desktop/Misc/DA - Materials/Project 1/title.ratings.csv")

# %% [markdown]
# # Understanding the data from "title.ratings.csv"

# %%
title_ratings_data.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
title_ratings_data.tail()
# Out:
#           tconst  averagerating  numvotes
# 73851  tt9805820            8.1        25
# 73852  tt9844256            7.5        24
# 73853  tt9851050            4.7        14
# 73854  tt9886934            7.0         5
# 73855  tt9894098            6.3       128

# %%
title_ratings_data.shape
# Out:
# (73856, 3)

# %%
title_ratings_data.columns
# Out:
# Index(['tconst', 'averagerating', 'numvotes'], dtype='object')

# %%
tn_movie_budgets_data = pd.read_csv("C:/Users/AnnieLiu/Desktop/Misc/DA - Materials/Project 1/tn.movie_budgets.csv")

# %% [markdown]
# # Understanding the data from "tn.movie_budgets.csv"

# %%
tn_movie_budgets_data.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
tn_movie_budgets_data.tail()
# Out:
#       id  release_date                          movie production_budget  \
# 5777  78  Dec 31, 2018                         Red 11            $7,000
# 5778  79   Apr 2, 1999                      Following            $6,000
# 5779  80  Jul 13, 2005  Return to the Land of Wonders            $5,000
# 5780  81  Sep 29, 2015           A Plague So Pleasant            $1,400
# 5781  82   Aug 5, 2005              My Date With Drew            $1,100
#
#      domestic_gross worldwide_gross
# 5777             $0              $0
# 5778        $48,482        $240,495
# 5779         $1,338          $1,338
# 5780             $0              $0
# 5781       $181,041        $181,041

# %%
tn_movie_budgets_data.shape
# Out:
# (5782, 6)

# %%
tn_movie_budgets_data.columns
# Out:
# Index(['id', 'release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross'],
#       dtype='object')

# %% [markdown]
# # Merge title_basics & title_ratings

# %%
title_basics_data.columns
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres'],
#       dtype='object')

# %%
title_ratings_data.columns
# Out:
# Index(['tconst', 'averagerating', 'numvotes'], dtype='object')

# %%
title_basics_ratings = pd.merge(title_basics_data, title_ratings_data)
title_basics_ratings.columns
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'averagerating', 'numvotes'],
#       dtype='object')

# %%
title_basics_ratings.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
title_basics_ratings.shape
# Out:
# (73856, 8)

# %% [markdown]
# # Merge title_basics_ratings & tn_movies_budgets

# %%
title_basics_ratings.columns
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'averagerating', 'numvotes'],
#       dtype='object')

# %%
tn_movie_budgets_data.columns
# Out:
# Index(['id', 'release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross'],
#       dtype='object')

# %%
basics_ratings_budgets = pd.merge(title_basics_ratings, tn_movie_budgets_data, left_on='primary_title', right_on='movie')
basics_ratings_budgets
# Out:
#          tconst  primary_title original_title  start_year  runtime_minutes  \
# 0     tt0249516     Foodfight!     Foodfight!        2012             91.0
# 1     tt0326592  The Overnight  The Overnight        2010             88.0
# 2     tt3844362  The Overnight  The Overnight        2015             79.0
# 3     tt0337692    On the Road    On the Road        2012            124.0
# 4     tt4339118    On the Road    On the Road        2014             89.0
# ...         ...            ...            ...         ...              ...
# 2870  tt8680254    Richard III    Richard III        2016              NaN
# 2871  tt8824064         Heroes         Heroes        2019             88.0
# 2872  tt8976772           Push           Push        2019             92.0
# 2873  tt9024106      Unplanned      Unplanned        2019            106.0
# 2874  tt9248762  The Terrorist  The Terrorist        2018              NaN
#
#                        genres  averagerating  numvotes  id  release_date  \
# 0     Action,Animation,Comedy            1.9      8248  26  Dec 31, 2012
# 1                         NaN            7.5        24  21  Jun 19, 2015
# 2              Comedy,Mystery            6.1     14828  21  Jun 19, 2015
# 3     Adventure,Drama,Romance            6.1     37886  17  Mar 22, 2013
# 4                       Drama            6.0         6  17  Mar 22, 2013
# ...                       ...            ...       ...  ..           ...
# 2870                    Drama            9.1        28  65  Dec 29, 1995
# 2871              Documentary            7.3         7  12  Oct 24, 2008
# 2872              Documentary            7.3        33  70   Feb 6, 2009
# 2873          Biography,Drama            6.3      5945  33  Mar 29, 2019
# 2874                 Thriller            6.0         6  48  Jan 14, 2000
#
#               movie production_budget domestic_gross worldwide_gross
# 0        Foodfight!       $45,000,000             $0         $73,706
# 1     The Overnight          $200,000     $1,109,808      $1,165,996
# 2     The Overnight          $200,000     $1,109,808      $1,165,996
# 3       On the Road       $25,000,000       $720,828      $9,313,302
# 4       On the Road       $25,000,000       $720,828      $9,313,302
# ...             ...               ...            ...             ...
# 2870    Richard III        $9,200,000     $2,684,904      $4,199,334
# 2871         Heroes          $400,000       $655,538        $655,538
# 2872           Push       $38,000,000    $31,811,527     $49,678,401
# 2873      Unplanned        $6,000,000    $18,107,621     $18,107,621
# 2874  The Terrorist           $25,000       $195,043        $195,043
#
# [2875 rows x 14 columns]

# %% [markdown]
# # Remove irrelevant columns

# %%
df_dropped = basics_ratings_budgets.drop(['tconst', 'primary_title', 'runtime_minutes', 'original_title', 'start_year', 'id'], axis=1)
df_dropped
# Out:
#                        genres  averagerating  numvotes  release_date  \
# 0     Action,Animation,Comedy            1.9      8248  Dec 31, 2012
# 1                         NaN            7.5        24  Jun 19, 2015
# 2              Comedy,Mystery            6.1     14828  Jun 19, 2015
# 3     Adventure,Drama,Romance            6.1     37886  Mar 22, 2013
# 4                       Drama            6.0         6  Mar 22, 2013
# ...                       ...            ...       ...           ...
# 2870                    Drama            9.1        28  Dec 29, 1995
# 2871              Documentary            7.3         7  Oct 24, 2008
# 2872              Documentary            7.3        33   Feb 6, 2009
# 2873          Biography,Drama            6.3      5945  Mar 29, 2019
# 2874                 Thriller            6.0         6  Jan 14, 2000
#
#               movie production_budget domestic_gross worldwide_gross
# 0        Foodfight!       $45,000,000             $0         $73,706
# 1     The Overnight          $200,000     $1,109,808      $1,165,996
# 2     The Overnight          $200,000     $1,109,808      $1,165,996
# 3       On the Road       $25,000,000       $720,828      $9,313,302
# 4       On the Road       $25,000,000       $720,828      $9,313,302
# ...             ...               ...            ...             ...
# 2870    Richard III        $9,200,000     $2,684,904      $4,199,334
# 2871         Heroes          $400,000       $655,538        $655,538
# 2872           Push       $38,000,000    $31,811,527     $49,678,401
# 2873      Unplanned        $6,000,000    $18,107,621     $18,107,621
# 2874  The Terrorist           $25,000       $195,043        $195,043
#
# [2875 rows x 8 columns]

# %% [markdown]
# # Duplicate movies dropped

# %%
df_dropped.duplicated().sum()
# Out:
# 0

# %%
df_dropped['movie'].duplicated().sum()
# Out:
# 749

# %%
df_movie_duplicate_dropped = df_dropped.drop_duplicates(subset='movie')
df_movie_duplicate_dropped
# Out:
#                        genres  averagerating  numvotes  release_date  \
# 0     Action,Animation,Comedy            1.9      8248  Dec 31, 2012
# 1                         NaN            7.5        24  Jun 19, 2015
# 3     Adventure,Drama,Romance            6.1     37886  Mar 22, 2013
# 6      Adventure,Comedy,Drama            7.3    275300  Dec 25, 2013
# 7          Action,Crime,Drama            6.5    105116  Sep 19, 2014
# ...                       ...            ...       ...           ...
# 2870                    Drama            9.1        28  Dec 29, 1995
# 2871              Documentary            7.3         7  Oct 24, 2008
# 2872              Documentary            7.3        33   Feb 6, 2009
# 2873          Biography,Drama            6.3      5945  Mar 29, 2019
# 2874                 Thriller            6.0         6  Jan 14, 2000
#
#                                 movie production_budget domestic_gross  \
# 0                          Foodfight!       $45,000,000             $0
# 1                       The Overnight          $200,000     $1,109,808
# 3                         On the Road       $25,000,000       $720,828
# 6     The Secret Life of Walter Mitty       $91,000,000    $58,236,838
# 7         A Walk Among the Tombstones       $28,000,000    $26,017,685
# ...                               ...               ...            ...
# 2870                      Richard III        $9,200,000     $2,684,904
# 2871                           Heroes          $400,000       $655,538
# 2872                             Push       $38,000,000    $31,811,527
# 2873                        Unplanned        $6,000,000    $18,107,621
# 2874                    The Terrorist           $25,000       $195,043
#
#      worldwide_gross
# 0            $73,706
# 1         $1,165,996
# 3         $9,313,302
# 6       $187,861,183
# 7        $62,108,587
# ...              ...
# 2870      $4,199,334
# 2871        $655,538
# 2872     $49,678,401
# 2873     $18,107,621
# 2874        $195,043
#
# [2126 rows x 8 columns]

# %%
df_movie_duplicate_dropped['movie'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Dealing with Missing Values

# %%
df_movie_duplicate_dropped.to_csv('df_movie_duplicated_dropped.csv')

# %%
df_movie_duplicate_dropped.isnull().sum()
# Out:
# genres               2
# averagerating        0
# numvotes             0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
df_movie_duplicate_dropped['genres'].value_counts()
# Out:
# Drama                         159
# Comedy                         81
# Comedy,Drama                   73
# Adventure,Animation,Comedy     68
# Comedy,Drama,Romance           66
#                              ...
# Drama,Family,Fantasy            1
# Action,Comedy,Sport             1
# Drama,Family,History            1
# Documentary,History             1
# Crime,Fantasy,Thriller          1
# Name: genres, Length: 284, dtype: int64

# %%
# Fill missing data with the most frequent value from one column

df_movie_duplicate_dropped['genres'].fillna(df_movie_duplicate_dropped['genres'].value_counts().index[0], inplace=True)
# Out:
# C:\Users\AnnieLiu\anaconda3\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
df_movie_duplicate_dropped['genres'].isna().sum()
# Out:
# 0

# %%
df_movie_duplicate_dropped.dtypes
# Out:
# genres                object
# averagerating        float64
# numvotes               int64
# release_date          object
# movie                 object
# production_budget     object
# domestic_gross        object
# worldwide_gross       object
# dtype: object

# %%
# Convert worldwide_gross and production_budget being $$ Objects to numbers

# %%
df_movie_duplicate_dropped['production_budget'] = df_movie_duplicate_dropped['production_budget'].str.replace('$','').str.replace(',', '')
df_movie_duplicate_dropped['production_budget'] = pd.to_numeric(df_movie_duplicate_dropped['production_budget'])
df_movie_duplicate_dropped['production_budget']
# Out:
# C:\Users\AnnieLiu\AppData\Local\Temp/ipykernel_98556/494982929.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_movie_duplicate_dropped['production_budget'] = df_movie_duplicate_dropped['production_budget'].str.replace('$','').str.replace(',', '')
# C:\Users\AnnieLiu\AppData\Local\Temp/ipykernel_98556/494982929.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movie_duplicate_dropped['production_budget'] = df_movie_duplicate_dropped['production_budget'].str.replace('$','').str.replace(',', '')
# C:\Users\AnnieLiu\AppData\Local\Temp/ipykernel_98556/494982929.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movie_duplicate_dropped['production_budget'] = pd.to_numeric(df_movie_duplicate_dropped['production_budget'])
# 0       45000000
# 1         200000
# 3       25000000
# 6       91000000
# 7       28000000
#           ...
# 2870     9200000
# 2871      400000
# 2872    38000000
# 2873     6000000
# 2874       25000
# Name: production_budget, Length: 2126, dtype: int64

# %%
df_movie_duplicate_dropped['worldwide_gross'] = df_movie_duplicate_dropped['worldwide_gross'].str.replace('$','').str.replace(',', '')
df_movie_duplicate_dropped['worldwide_gross'] = pd.to_numeric(df_movie_duplicate_dropped['worldwide_gross'])
df_movie_duplicate_dropped['worldwide_gross']
# Out:
# C:\Users\AnnieLiu\AppData\Local\Temp/ipykernel_98556/1566134900.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_movie_duplicate_dropped['worldwide_gross'] = df_movie_duplicate_dropped['worldwide_gross'].str.replace('$','').str.replace(',', '')
# C:\Users\AnnieLiu\AppData\Local\Temp/ipykernel_98556/1566134900.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movie_duplicate_dropped['worldwide_gross'] = df_movie_duplicate_dropped['worldwide_gross'].str.replace('$','').str.replace(',', '')
# C:\Users\AnnieLiu\AppData\Local\Temp/ipykernel_98556/1566134900.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movie_duplicate_dropped['worldwide_gross'] = pd.to_numeric(df_movie_duplicate_dropped['worldwide_gross'])
# 0           73706
# 1         1165996
# 3         9313302
# 6       187861183
# 7        62108587
#           ...
# 2870      4199334
# 2871       655538
# 2872     49678401
# 2873     18107621
# 2874       195043
# Name: worldwide_gross, Length: 2126, dtype: int64

# %% [markdown]
# # Unique genres

# %%
df_movie_duplicate_dropped['genres']
# Out:
# 0       Action,Animation,Comedy
# 1                         Drama
# 3       Adventure,Drama,Romance
# 6        Adventure,Comedy,Drama
# 7            Action,Crime,Drama
#                  ...
# 2870                      Drama
# 2871                Documentary
# 2872                Documentary
# 2873            Biography,Drama
# 2874                   Thriller
# Name: genres, Length: 2126, dtype: object

# %%
list1 =[]
for value in df_movie_duplicate_dropped['genres']:
    list1.append(value.split(','))

# %%
list1
# Out:
# [['Action', 'Animation', 'Comedy'],
#  ['Drama'],
#  ['Adventure', 'Drama', 'Romance'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Action', 'Crime', 'Drama'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Family'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Thriller'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Action', 'Drama', 'Family'],
#  ['Drama', 'Romance', 'Sci-Fi'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Biography', 'Drama', 'History'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Romance', 'War'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Animation'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Adventure', 'Drama', 'Fantasy'],
#  ['Horror', 'Thriller'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Crime', 'Thriller'],
#  ['Horror', 'Thriller'],
#  ['Comedy', 'Horror'],
#  ['Drama'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Comedy', 'Drama', 'Music'],
#  ['Action', 'Thriller'],
#  ['Drama', 'Fantasy'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure', 'Crime'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Adventure', 'Animation'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Adventure', 'Drama', 'History'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'History', 'Romance'],
#  ['Comedy', 'Family'],
#  ['Adventure', 'Comedy', 'Family'],
#  ['Drama', 'Horror', 'Mystery'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Documentary', 'Music'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Animation', 'Drama'],
#  ['Crime', 'Drama'],
#  ['Drama', 'Fantasy', 'Horror'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Biography', 'Drama'],
#  ['Adventure', 'Comedy', 'Fantasy'],
#  ['Biography', 'Drama'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Drama'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Biography', 'Comedy', 'Drama'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Family', 'Fantasy'],
#  ['Comedy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Comedy', 'Romance'],
#  ['Drama', 'War'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Adventure', 'Drama', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Horror'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Drama', 'Fantasy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Adventure', 'Animation', 'Family'],
#  ['Biography', 'Drama'],
#  ['Action', 'Crime', 'Drama'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Action', 'Crime', 'Horror'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Adventure', 'Drama', 'Thriller'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Comedy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Action', 'Adventure', 'Animation'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Horror', 'Mystery', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Action', 'Horror', 'Sci-Fi'],
#  ['Drama'],
#  ['Action', 'Adventure', 'Family'],
#  ['Comedy', 'Crime', 'Thriller'],
#  ['Action', 'Mystery', 'Thriller'],
#  ['Action', 'Drama', 'Sci-Fi'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Crime', 'Drama', 'Horror'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Crime', 'Drama', 'Horror'],
#  ['Action', 'Adventure', 'Family'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Crime', 'Drama', 'History'],
#  ['Adventure', 'Drama', 'Family'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Biography', 'Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Comedy'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Action', 'Adventure', 'Animation'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Drama', 'Romance', 'War'],
#  ['Horror', 'Thriller'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Action', 'Animation', 'Comedy'],
#  ['Drama', 'Fantasy'],
#  ['Biography', 'Drama'],
#  ['Action'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Crime', 'Drama', 'History'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Biography', 'Drama', 'Music'],
#  ['Drama'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Biography', 'Drama', 'Thriller'],
#  ['Biography', 'Drama', 'Family'],
#  ['Horror', 'Thriller'],
#  ['Drama'],
#  ['Action', 'Comedy'],
#  ['Action', 'Fantasy', 'Western'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Fantasy', 'Horror', 'Mystery'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Action', 'Fantasy', 'Horror'],
#  ['Action', 'Comedy', 'Romance'],
#  ['Action', 'Family', 'Fantasy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Family'],
#  ['Adventure', 'Comedy', 'Family'],
#  ['Action', 'Crime', 'Sci-Fi'],
#  ['Comedy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama'],
#  ['Drama', 'Romance'],
#  ['Adventure', 'Comedy', 'Family'],
#  ['Comedy', 'Drama', 'Music'],
#  ['Comedy'],
#  ['Action', 'Fantasy', 'Thriller'],
#  ['Biography', 'Drama', 'Fantasy'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Action', 'Drama', 'Fantasy'],
#  ['Comedy', 'Fantasy', 'Horror'],
#  ['Horror', 'Thriller'],
#  ['Biography', 'Comedy', 'Drama'],
#  ['Drama'],
#  ['Action', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Biography', 'Drama'],
#  ['Animation'],
#  ['Adventure', 'Comedy', 'Sci-Fi'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Action', 'Adventure', 'Horror'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Action', 'Comedy', 'Romance'],
#  ['Crime', 'Thriller'],
#  ['Adventure', 'Comedy', 'Family'],
#  ['Horror'],
#  ['Action', 'Comedy', 'Documentary'],
#  ['Drama', 'Romance'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Biography', 'Drama'],
#  ['Biography', 'Comedy', 'Drama'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Drama', 'Music', 'Musical'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Horror', 'Thriller'],
#  ['Mystery', 'Thriller'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Animation'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Action', 'Crime', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Drama', 'Mystery'],
#  ['Drama', 'Fantasy', 'Romance'],
#  ['Documentary'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Drama', 'Family'],
#  ['Drama', 'Horror', 'Mystery'],
#  ['Drama', 'Romance'],
#  ['Adventure', 'Fantasy'],
#  ['Comedy'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Adventure', 'Biography', 'Comedy'],
#  ['Crime', 'Drama', 'Horror'],
#  ['Drama', 'Horror', 'Mystery'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Drama', 'Music', 'Romance'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Biography', 'Comedy', 'Crime'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Crime', 'Drama', 'Fantasy'],
#  ['Action', 'Drama', 'Romance'],
#  ['Adventure', 'Comedy', 'Family'],
#  ['Comedy', 'Drama'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama', 'Sport'],
#  ['Drama'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Action', 'Adventure', 'Western'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Drama'],
#  ['Action', 'Crime', 'Mystery'],
#  ['Animation'],
#  ['Drama', 'Fantasy', 'Romance'],
#  ['Adventure', 'Biography', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Crime', 'Drama'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Comedy', 'Sci-Fi'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Drama', 'Romance', 'Sci-Fi'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Mystery', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Animation'],
#  ['Action', 'Drama', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Horror'],
#  ['Comedy', 'Family', 'Romance'],
#  ['Adventure', 'Fantasy', 'Mystery'],
#  ['Adventure', 'Comedy', 'Music'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Drama', 'Thriller'],
#  ['Biography', 'Drama'],
#  ['Documentary'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Drama', 'Fantasy', 'Horror'],
#  ['Comedy'],
#  ['Action'],
#  ['Biography', 'Drama'],
#  ['Adventure', 'Comedy'],
#  ['Comedy', 'Sci-Fi'],
#  ['Comedy'],
#  ['Comedy'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Crime', 'Sci-Fi'],
#  ['Drama', 'Fantasy', 'Romance'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Action', 'Horror', 'Thriller'],
#  ['Adventure', 'Comedy', 'Fantasy'],
#  ['Thriller'],
#  ['Horror', 'Thriller'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Comedy'],
#  ['Documentary'],
#  ['Comedy'],
#  ['Action', 'Comedy'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Action', 'Fantasy', 'War'],
#  ['Action', 'Drama', 'Fantasy'],
#  ['Crime', 'Horror', 'Thriller'],
#  ['Adventure', 'Comedy', 'Crime'],
#  ['Drama', 'Mystery', 'War'],
#  ['Action'],
#  ['Horror'],
#  ['Action', 'Crime', 'Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Horror', 'Mystery'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Adventure', 'Comedy'],
#  ['Biography', 'Drama', 'Thriller'],
#  ['Fantasy', 'Horror', 'Thriller'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Crime', 'Mystery', 'Thriller'],
#  ['Action', 'Comedy', 'Family'],
#  ['Comedy', 'Drama', 'Fantasy'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Crime', 'Drama'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Comedy', 'Crime', 'Romance'],
#  ['Drama', 'History', 'War'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Horror'],
#  ['Biography', 'Drama'],
#  ['Action', 'Comedy', 'Family'],
#  ['Fantasy', 'Horror', 'Thriller'],
#  ['Action', 'Comedy', 'Fantasy'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Drama', 'Sport'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Drama', 'Music', 'Romance'],
#  ['Comedy'],
#  ['Drama', 'Fantasy'],
#  ['Action', 'Comedy', 'Horror'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Animation'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Musical'],
#  ['Comedy', 'Romance'],
#  ['Adventure', 'Animation', 'Family'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Crime', 'Drama'],
#  ['Drama'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Biography', 'Drama', 'War'],
#  ['Action', 'Drama', 'Sci-Fi'],
#  ['Comedy', 'Drama', 'Fantasy'],
#  ['Drama', 'Horror', 'Thriller'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Adventure', 'Comedy', 'Family'],
#  ['Adventure', 'Drama', 'Horror'],
#  ['Comedy'],
#  ['Action', 'Drama', 'Mystery'],
#  ['Drama'],
#  ['Action', 'Adventure', 'Romance'],
#  ['Action', 'Crime', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Adventure', 'Drama', 'Sport'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Adventure', 'Drama', 'Fantasy'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Horror', 'Mystery'],
#  ['Crime', 'Horror', 'Mystery'],
#  ['Biography', 'Drama'],
#  ['Action', 'Adventure', 'Mystery'],
#  ['Animation', 'Horror'],
#  ['Comedy'],
#  ['Drama', 'Romance', 'Sci-Fi'],
#  ['Comedy', 'Romance'],
#  ['Thriller'],
#  ['Comedy', 'Crime', 'Thriller'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Comedy', 'Drama', 'Musical'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Horror', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Action', 'Crime', 'Sci-Fi'],
#  ['Action', 'Thriller'],
#  ['Adventure', 'Drama', 'Romance'],
#  ['Adventure', 'Fantasy'],
#  ['Drama', 'Fantasy', 'Music'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Drama', 'Romance', 'Sci-Fi'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Drama'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Adventure', 'Crime', 'Drama'],
#  ['Comedy'],
#  ['Action', 'Thriller'],
#  ['Action', 'Drama', 'Mystery'],
#  ['Biography', 'Comedy', 'Drama'],
#  ['Drama'],
#  ['Drama', 'Thriller', 'War'],
#  ['Horror', 'Mystery'],
#  ['Horror', 'Thriller'],
#  ['Action', 'Comedy', 'Horror'],
#  ['Drama', 'Fantasy', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Romance', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure', 'Mystery'],
#  ['Drama', 'Sci-Fi'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Crime', 'Drama', 'Horror'],
#  ['Action', 'Adventure', 'Biography'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy', 'Family'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Horror', 'Thriller'],
#  ['Action', 'Thriller'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Drama', 'Mystery'],
#  ['Action', 'Mystery', 'Thriller'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Action', 'Fantasy', 'Horror'],
#  ['Adventure', 'Drama', 'Western'],
#  ['Drama', 'Romance'],
#  ['Drama'],
#  ['Comedy', 'Romance', 'Sport'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Comedy'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy'],
#  ['Comedy', 'Mystery'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Drama', 'History'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Comedy', 'Family', 'Romance'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Action', 'Fantasy', 'Horror'],
#  ['Drama', 'History', 'War'],
#  ['Comedy', 'Drama'],
#  ['Adventure', 'Crime', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Drama', 'Family', 'Music'],
#  ['Action', 'Fantasy', 'Horror'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Action', 'Crime'],
#  ['Biography', 'Drama', 'Family'],
#  ['Documentary'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Romance'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Crime', 'Drama'],
#  ['Action', 'Horror'],
#  ['Horror', 'Thriller'],
#  ['Documentary'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Comedy', 'Horror'],
#  ['Drama', 'Fantasy', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy', 'Drama', 'Fantasy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Drama', 'Horror', 'Sci-Fi'],
#  ['Comedy', 'Drama'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Animation'],
#  ['Adventure', 'Mystery', 'Sci-Fi'],
#  ['Drama'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Drama'],
#  ['Drama', 'Sci-Fi', 'Thriller'],
#  ['Documentary'],
#  ['Adventure', 'Crime', 'Drama'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Action', 'Crime', 'Drama'],
#  ['Action', 'Adventure'],
#  ['Animation', 'Family'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Drama', 'Family'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Drama', 'Horror', 'Sci-Fi'],
#  ['Drama'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Drama'],
#  ['Action', 'Comedy', 'Romance'],
#  ['Drama', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Family'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Comedy'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Comedy', 'Sci-Fi'],
#  ['Comedy', 'Horror'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Documentary'],
#  ['Biography', 'Drama', 'Musical'],
#  ['Fantasy', 'Horror', 'Mystery'],
#  ['Crime', 'Mystery', 'Thriller'],
#  ['Action', 'Drama', 'War'],
#  ['Adventure', 'Animation', 'Family'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Comedy', 'Fantasy'],
#  ['Horror', 'Thriller'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Action', 'Adventure', 'Animation'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Drama'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Horror'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Crime'],
#  ['Comedy', 'Fantasy', 'Horror'],
#  ['Action', 'Fantasy', 'Thriller'],
#  ['Horror', 'Thriller'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Adventure', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Action', 'Adventure', 'Crime'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Drama', 'Western'],
#  ['Horror', 'Sci-Fi', 'Thriller'],
#  ['Drama', 'Thriller'],
#  ['Drama'],
#  ['Comedy'],
#  ['Action', 'Crime', 'Drama'],
#  ['Horror', 'Thriller'],
#  ['Adventure', 'Comedy'],
#  ['Comedy', 'Horror', 'Sci-Fi'],
#  ['Drama', 'Sci-Fi'],
#  ['Drama'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Documentary'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Music'],
#  ['Horror', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Drama', 'Sci-Fi'],
#  ['Biography', 'Drama', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Crime', 'Drama'],
#  ['Drama', 'Horror', 'Sci-Fi'],
#  ['Horror'],
#  ['Action', 'Fantasy', 'Horror'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Comedy', 'Romance', 'Sport'],
#  ['Comedy', 'Crime', 'Thriller'],
#  ['Drama', 'History'],
#  ['Adventure', 'Biography', 'Drama'],
#  ['Drama'],
#  ['Comedy', 'Horror', 'Romance'],
#  ['Action', 'Crime', 'Drama'],
#  ['Comedy'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Drama', 'Romance', 'Sci-Fi'],
#  ['Action', 'Thriller'],
#  ['Biography', 'Drama', 'History'],
#  ['Drama', 'Romance'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Drama', 'Music'],
#  ['Biography', 'Drama', 'History'],
#  ['Crime', 'Drama', 'Horror'],
#  ['Drama', 'Fantasy', 'Romance'],
#  ['Drama'],
#  ['Documentary'],
#  ['Horror'],
#  ['Drama'],
#  ['Drama', 'War'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Documentary', 'History'],
#  ['Drama', 'Family'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Comedy'],
#  ['Drama', 'History', 'War'],
#  ['Action', 'Adventure', 'Crime'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Drama', 'History', 'War'],
#  ['Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Biography', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama'],
#  ['Horror', 'Thriller'],
#  ['Comedy'],
#  ['Action', 'Thriller'],
#  ['Documentary'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Horror', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy', 'Crime', 'Romance'],
#  ['Drama', 'Sci-Fi'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Biography', 'Crime'],
#  ['Action', 'Adventure', 'Family'],
#  ['Comedy', 'Horror', 'Romance'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Family', 'Sport'],
#  ['Action', 'Mystery', 'Thriller'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Horror', 'Mystery'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Biography', 'Drama', 'Family'],
#  ['Action', 'Comedy', 'Romance'],
#  ['Biography', 'Comedy', 'Drama'],
#  ['Drama', 'Fantasy', 'Horror'],
#  ['Drama', 'Horror', 'Mystery'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Action', 'Adventure', 'Crime'],
#  ['Drama'],
#  ['Action', 'Mystery', 'Thriller'],
#  ['Crime', 'Drama'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Crime', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Drama'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Comedy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Fantasy', 'Romance'],
#  ['Action', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Family', 'History'],
#  ['Documentary', 'Sport'],
#  ['Comedy'],
#  ['Biography', 'Documentary', 'Sport'],
#  ['Drama', 'Horror', 'Mystery'],
#  ['Action', 'Fantasy', 'Horror'],
#  ['Action', 'Horror'],
#  ['Comedy', 'Fantasy', 'Horror'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Thriller'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Crime', 'Drama'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Biography', 'Drama', 'History'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Horror'],
#  ['Action', 'Horror', 'Sci-Fi'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Horror'],
#  ['Comedy', 'Drama'],
#  ['Family'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Western'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Drama'],
#  ['Mystery', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Sci-Fi'],
#  ['Horror'],
#  ['Comedy', 'Romance'],
#  ['Horror', 'Thriller'],
#  ['Documentary'],
#  ['Adventure', 'Animation', 'Family'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Drama'],
#  ['Comedy'],
#  ['Drama'],
#  ['Action', 'Crime', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Fantasy'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Comedy', 'Horror'],
#  ['Comedy', 'Drama'],
#  ['Crime', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Drama', 'Family'],
#  ['Thriller'],
#  ['Drama', 'Romance'],
#  ['Crime', 'Documentary'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Animation'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Action', 'Crime', 'Drama'],
#  ['Action', 'Comedy', 'Sport'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Drama', 'History', 'Thriller'],
#  ['Comedy', 'Family'],
#  ['Mystery', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Crime', 'Drama'],
#  ['Drama', 'Fantasy', 'Mystery'],
#  ['Biography', 'Drama'],
#  ['Drama', 'Fantasy', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Biography', 'Drama', 'Romance'],
#  ['Drama'],
#  ['Drama', 'Family', 'Fantasy'],
#  ['Comedy', 'Drama', 'Sport'],
#  ['Crime', 'Drama'],
#  ['Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Biography'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Action', 'Comedy'],
#  ['Biography', 'Drama', 'Music'],
#  ['Comedy'],
#  ['Drama', 'Thriller'],
#  ['Comedy', 'Romance', 'Sci-Fi'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Drama', 'Family', 'Sport'],
#  ['Crime', 'Mystery', 'Thriller'],
#  ['Biography', 'Comedy', 'Drama'],
#  ['Comedy'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama', 'Horror', 'Thriller'],
#  ['Drama', 'Mystery'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Action', 'Romance', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Thriller'],
#  ['Documentary'],
#  ['Drama'],
#  ['Horror'],
#  ['Thriller'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Crime', 'Drama', 'Horror'],
#  ['Horror'],
#  ['Drama', 'Fantasy', 'Mystery'],
#  ['Comedy'],
#  ['Comedy', 'Drama'],
#  ['Animation', 'Family', 'Fantasy'],
#  ['Comedy'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Drama'],
#  ['Comedy'],
#  ['Comedy', 'Family'],
#  ['Drama', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Comedy', 'Western'],
#  ['Drama', 'Romance', 'Thriller'],
#  ['Documentary', 'Music'],
#  ['Drama'],
#  ['Horror'],
#  ['Biography', 'Drama'],
#  ['Biography', 'Comedy', 'Crime'],
#  ['Adventure', 'Animation', 'Drama'],
#  ['Drama', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Drama', 'Sci-Fi'],
#  ['Biography'],
#  ['Adventure', 'Horror', 'Sci-Fi'],
#  ['Comedy', 'Drama', 'Music'],
#  ['Comedy'],
#  ['Action', 'Crime', 'Mystery'],
#  ['Crime', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Horror'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Drama'],
#  ['Drama', 'Fantasy', 'Musical'],
#  ['Comedy', 'Crime'],
#  ['Drama'],
#  ['Comedy'],
#  ['Drama', 'Horror', 'Mystery'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Action', 'Comedy', 'Horror'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Crime', 'Drama'],
#  ['Action', 'Comedy', 'Horror'],
#  ['Crime', 'Drama'],
#  ['Biography', 'Drama', 'Music'],
#  ['Drama'],
#  ['Horror', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Horror', 'Thriller'],
#  ['Crime', 'Drama'],
#  ['Fantasy', 'Horror', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Biography', 'Crime', 'Documentary'],
#  ['Drama', 'Romance'],
#  ['Action'],
#  ['Documentary'],
#  ['Drama'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Biography', 'Drama', 'Music'],
#  ['Action', 'Crime', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Crime', 'Drama'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Fantasy', 'Horror'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Action', 'Horror', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Fantasy', 'Musical'],
#  ['Action'],
#  ['Drama'],
#  ['Comedy', 'Fantasy', 'Horror'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Thriller'],
#  ['Crime', 'Thriller'],
#  ['Documentary'],
#  ['Horror'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Drama', 'Horror', 'Mystery'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Horror', 'Mystery', 'Sci-Fi'],
#  ['Drama', 'Horror', 'Mystery'],
#  ['Biography', 'Comedy', 'Drama'],
#  ['Thriller'],
#  ['Comedy', 'Drama'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Drama', 'Thriller'],
#  ['Comedy'],
#  ['Horror'],
#  ['Horror'],
#  ['Documentary', 'Music'],
#  ['Drama'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Documentary'],
#  ['Action', 'Biography', 'Drama'],
#  ['Action', 'Thriller'],
#  ['Drama', 'Horror', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Drama'],
#  ['Comedy', 'Drama'],
#  ['Crime', 'Drama', 'Horror'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Mystery', 'Sci-Fi'],
#  ['Drama', 'Thriller'],
#  ['Comedy'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Comedy', 'Drama', 'Mystery'],
#  ['Fantasy'],
#  ['Drama'],
#  ['Comedy', 'Drama', 'Music'],
#  ['Drama'],
#  ['Drama', 'Sport'],
#  ['Drama', 'Romance', 'Sci-Fi'],
#  ['Crime', 'Drama', 'Family'],
#  ['Crime', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Crime', 'Mystery', 'Thriller'],
#  ['Drama', 'Music', 'Romance'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Drama'],
#  ['Documentary'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Drama', 'History', 'War'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Horror', 'Sci-Fi'],
#  ['Mystery', 'Sci-Fi', 'Thriller'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Action', 'Adventure', 'Mystery'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Biography', 'Documentary'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Action', 'Crime', 'Drama'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Crime', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Crime', 'Horror'],
#  ['Drama'],
#  ['Animation', 'Sci-Fi'],
#  ['Action', 'Thriller'],
#  ['Drama', 'Music', 'Romance'],
#  ['Sci-Fi', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Adventure', 'Biography', 'Drama'],
#  ['Biography', 'Drama', 'Thriller'],
#  ['Horror', 'Mystery'],
#  ['Comedy'],
#  ['Drama', 'Mystery', 'Romance'],
#  ['Action', 'Adventure', 'Mystery'],
#  ['Drama', 'Mystery', 'Romance'],
#  ['Horror', 'Thriller'],
#  ['Drama'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Animation'],
#  ['Action', 'Drama', 'Mystery'],
#  ['Comedy', 'Drama'],
#  ['Action'],
#  ['Crime', 'Thriller'],
#  ['Drama'],
#  ['Drama'],
#  ['Comedy'],
#  ['Drama', 'Western'],
#  ['Action', 'Comedy', 'Horror'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Action', 'Crime', 'Drama'],
#  ['Action', 'Horror', 'Sci-Fi'],
#  ['Comedy'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Comedy', 'Music', 'Romance'],
#  ['Comedy'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Action', 'Drama', 'History'],
#  ['Crime', 'Drama', 'Horror'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Biography', 'Comedy', 'Drama'],
#  ['Drama'],
#  ['Drama', 'Music'],
#  ['Documentary'],
#  ['Adventure', 'Drama', 'Thriller'],
#  ['Drama'],
#  ...]

# %%
list2= []
for item in list1:
    for item1 in item:
       list2.append(item1)

# %%
list2
# Out:
# ['Action',
#  'Animation',
#  'Comedy',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Crime',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Family',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Thriller',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Drama',
#  'Family',
#  'Drama',
#  'Romance',
#  'Sci-Fi',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Biography',
#  'Drama',
#  'History',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Romance',
#  'War',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'Sport',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Horror',
#  'Thriller',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Crime',
#  'Thriller',
#  'Horror',
#  'Thriller',
#  'Comedy',
#  'Horror',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Action',
#  'Thriller',
#  'Drama',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Crime',
#  'Comedy',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'History',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Drama',
#  'History',
#  'Romance',
#  'Comedy',
#  'Family',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Drama',
#  'Horror',
#  'Mystery',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Romance',
#  'Documentary',
#  'Music',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Fantasy',
#  'Horror',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'Adventure',
#  'Comedy',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Biography',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Comedy',
#  'Romance',
#  'Drama',
#  'War',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Adventure',
#  'Drama',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Horror',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Comedy',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Drama',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Animation',
#  'Family',
#  'Biography',
#  'Drama',
#  'Action',
#  'Crime',
#  'Drama',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Crime',
#  'Horror',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Drama',
#  'Thriller',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Horror',
#  'Mystery',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Horror',
#  'Sci-Fi',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Family',
#  'Comedy',
#  'Crime',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Drama',
#  'Sci-Fi',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Crime',
#  'Drama',
#  'Horror',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Horror',
#  'Action',
#  'Adventure',
#  'Family',
#  'Biography',
#  'Drama',
#  'Sport',
#  'Crime',
#  'Drama',
#  'History',
#  'Adventure',
#  'Drama',
#  'Family',
#  'Comedy',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'War',
#  'Horror',
#  'Thriller',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Action',
#  'Drama',
#  'Thriller',
#  'Biography',
#  'Crime',
#  'Drama',
#  'Action',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Animation',
#  'Comedy',
#  'Drama',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'Action',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Crime',
#  'Drama',
#  'History',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Music',
#  'Drama',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Biography',
#  'Drama',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Family',
#  'Horror',
#  'Thriller',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Action',
#  'Fantasy',
#  'Western',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Horror',
#  'Mystery',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Fantasy',
#  'Horror',
#  'Action',
#  'Comedy',
#  'Romance',
#  'Action',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Comedy',
#  'Family',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Action',
#  'Crime',
#  'Sci-Fi',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Comedy',
#  'Action',
#  'Fantasy',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Action',
#  'Drama',
#  'Fantasy',
#  'Comedy',
#  'Fantasy',
#  'Horror',
#  'Horror',
#  'Thriller',
#  'Biography',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Action',
#  'Thriller',
#  'Comedy',
#  'Romance',
#  'Action',
#  'Biography',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Sci-Fi',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Action',
#  'Adventure',
#  'Horror',
#  'Biography',
#  'Drama',
#  'Sport',
#  'Action',
#  'Comedy',
#  'Romance',
#  'Crime',
#  'Thriller',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Horror',
#  'Action',
#  'Comedy',
#  'Documentary',
#  'Drama',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Biography',
#  'Drama',
#  'Biography',
#  'Comedy',
#  'Drama',
#  'Biography',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Music',
#  'Musical',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Horror',
#  'Thriller',
#  'Mystery',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Sport',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Action',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Romance',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Drama',
#  'Mystery',
#  'Drama',
#  'Fantasy',
#  'Romance',
#  'Documentary',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Drama',
#  'Family',
#  'Drama',
#  'Horror',
#  'Mystery',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Adventure',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Horror',
#  'Drama',
#  'Horror',
#  'Mystery',
#  'Drama',
#  'Romance',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Comedy',
#  'Romance',
#  'Comedy',
#  'Drama',
#  'Family',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Fantasy',
#  'Action',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Comedy',
#  'Drama',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Drama',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Sport',
#  'Drama',
#  'Biography',
#  'Drama',
#  'Sport',
#  'Action',
#  'Adventure',
#  'Western',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Drama',
#  'Action',
#  'Crime',
#  'Mystery',
#  'Animation',
#  'Drama',
#  'Fantasy',
#  'Romance',
#  'Adventure',
#  'Biography',
#  'Drama',
#  'Comedy',
#  'Romance',
#  'Crime',
#  'Drama',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Comedy',
#  'Sci-Fi',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Biography',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Romance',
#  'Drama',
#  'Romance',
#  'Sci-Fi',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Mystery',
#  'Sci-Fi',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Action',
#  'Drama',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Horror',
#  'Comedy',
#  'Family',
#  'Romance',
#  'Adventure',
#  'Fantasy',
#  'Mystery',
#  'Adventure',
#  'Comedy',
#  'Music',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Drama',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Documentary',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Drama',
#  'Fantasy',
#  'Horror',
#  'Comedy',
#  'Action',
#  'Biography',
#  'Drama',
#  'Adventure',
#  'Comedy',
#  'Comedy',
#  'Sci-Fi',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Sci-Fi',
#  'Thriller',
#  'Action',
#  'Crime',
#  'Sci-Fi',
#  'Drama',
#  'Fantasy',
#  'Romance',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Horror',
#  'Thriller',
#  'Adventure',
#  'Comedy',
#  'Fantasy',
#  'Thriller',
#  'Horror',
#  'Thriller',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Biography',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Documentary',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Fantasy',
#  'War',
#  'Action',
#  'Drama',
#  'Fantasy',
#  'Crime',
#  'Horror',
#  'Thriller',
#  'Adventure',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'War',
#  'Action',
#  'Horror',
#  'Action',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Horror',
#  'Mystery',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Adventure',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'Thriller',
#  'Fantasy',
#  'Horror',
#  'Thriller',
#  'Action',
#  'Sci-Fi',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Crime',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Comedy',
#  'Family',
#  'Comedy',
#  'Drama',
#  'Fantasy',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Crime',
#  'Drama',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Comedy',
#  'Crime',
#  'Romance',
#  'Drama',
#  'History',
#  'War',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Comedy',
#  'Romance',
#  'Horror',
#  'Biography',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Horror',
#  'Thriller',
#  'Action',
#  'Comedy',
#  'Fantasy',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Sport',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Drama',
#  'Music',
#  'Romance',
#  'Comedy',
#  'Drama',
#  'Fantasy',
#  'Action',
#  'Comedy',
#  'Horror',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Musical',
#  'Comedy',
#  'Romance',
#  'Adventure',
#  'Animation',
#  'Family',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'War',
#  'Action',
#  'Drama',
#  'Sci-Fi',
#  'Comedy',
#  'Drama',
#  'Fantasy',
#  'Drama',
#  'Horror',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Adventure',
#  'Drama',
#  'Horror',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Mystery',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Romance',
#  'Action',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Romance',
#  'Adventure',
#  'Drama',
#  'Sport',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Horror',
#  'Mystery',
#  'Crime',
#  'Horror',
#  'Mystery',
#  'Biography',
#  ...]

# %%
un_list = []
for item in list2:
    if item not in un_list:
        un_list.append(item)

# %%
un_list
# Out:
# ['Action',
#  'Animation',
#  'Comedy',
#  'Drama',
#  'Adventure',
#  'Romance',
#  'Crime',
#  'Sci-Fi',
#  'Family',
#  'Thriller',
#  'Horror',
#  'Mystery',
#  'Biography',
#  'History',
#  'War',
#  'Fantasy',
#  'Sport',
#  'Music',
#  'Documentary',
#  'Western',
#  'Musical',
#  'News']

# %%
list2= []
for item in list1:
    for item1 in item:
       list2.append(item1)

# %%
from collections import Counter

# %%
Counter(list2)
# Out:
# Counter({'Action': 522,
#          'Animation': 118,
#          'Comedy': 650,
#          'Drama': 1076,
#          'Adventure': 395,
#          'Romance': 256,
#          'Crime': 301,
#          'Sci-Fi': 170,
#          'Family': 115,
#          'Thriller': 365,
#          'Horror': 266,
#          'Mystery': 166,
#          'Biography': 165,
#          'History': 55,
#          'War': 27,
#          'Fantasy': 145,
#          'Sport': 46,
#          'Music': 60,
#          'Documentary': 118,
#          'Western': 14,
#          'Musical': 12,
#          'News': 1})

# %%
from collections import Counter
d = Counter({'Action': 522,'Animation': 118,'Comedy': 650,'Drama': 1076,'Adventure': 395,'Romance': 256,'Crime': 301,'Sci-Fi': 170,'Family': 115,'Thriller': 365,'Horror': 266,'Mystery': 166,'Biography': 165,'History': 55,'War': 27,'Fantasy': 145,'Sport': 46,'Music': 60,'Documentary': 118,'Western': 14,'Musical': 12,'News': 1})
genres_produced = pd.DataFrame.from_dict(d, orient='index').reset_index()
genres_produced
# Out:
#           index     0
# 0        Action   522
# 1     Animation   118
# 2        Comedy   650
# 3         Drama  1076
# 4     Adventure   395
# 5       Romance   256
# 6         Crime   301
# 7        Sci-Fi   170
# 8        Family   115
# 9      Thriller   365
# 10       Horror   266
# 11      Mystery   166
# 12    Biography   165
# 13      History    55
# 14          War    27
# 15      Fantasy   145
# 16        Sport    46
# 17        Music    60
# 18  Documentary   118
# 19      Western    14
# 20      Musical    12
# 21         News     1

# %%
genres_produced = genres_produced.rename(columns={'index':'Genre', 0:'Count'})
genres_produced
# Out:
#           Genre  Count
# 0        Action    522
# 1     Animation    118
# 2        Comedy    650
# 3         Drama   1076
# 4     Adventure    395
# 5       Romance    256
# 6         Crime    301
# 7        Sci-Fi    170
# 8        Family    115
# 9      Thriller    365
# 10       Horror    266
# 11      Mystery    166
# 12    Biography    165
# 13      History     55
# 14          War     27
# 15      Fantasy    145
# 16        Sport     46
# 17        Music     60
# 18  Documentary    118
# 19      Western     14
# 20      Musical     12
# 21         News      1

# %%
genres_produced.set_index("Genre", inplace=True)
genres_produced
# Out:
#              Count
# Genre
# Action         522
# Animation      118
# Comedy         650
# Drama         1076
# Adventure      395
# Romance        256
# Crime          301
# Sci-Fi         170
# Family         115
# Thriller       365
# Horror         266
# Mystery        166
# Biography      165
# History         55
# War             27
# Fantasy        145
# Sport           46
# Music           60
# Documentary    118
# Western         14
# Musical         12
# News             1

# %%
sns.barplot(x='Count',y=genres_produced.index,data=genres_produced)
plt.title("Genres by count")
# Out:
# Text(0.5, 1.0, 'Genres by count')

# %% [markdown]
# ####  <span style="color:green">Looks like Drama films were most popular by # of genres produced, followed by Comedy and Action</span>.

# %% [markdown]
# # Movie genre profit

# %%
for ind, row in df_movie_duplicate_dropped.iterrows():
    df_movie_duplicate_dropped.loc[ind, "worldwide_profit"] = row['worldwide_gross'] - row['production_budget']
# Out:
# C:\Users\AnnieLiu\anaconda3\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\AnnieLiu\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_movie_duplicate_dropped.head()
# Out:
#                     genres  averagerating  numvotes  release_date  \
# 0  Action,Animation,Comedy            1.9      8248  Dec 31, 2012
# 1                    Drama            7.5        24  Jun 19, 2015
# 3  Adventure,Drama,Romance            6.1     37886  Mar 22, 2013
# 6   Adventure,Comedy,Drama            7.3    275300  Dec 25, 2013
# 7       Action,Crime,Drama            6.5    105116  Sep 19, 2014
#
#                              movie  production_budget domestic_gross  \
# 0                       Foodfight!           45000000             $0
# 1                    The Overnight             200000     $1,109,808
# 3                      On the Road           25000000       $720,828
# 6  The Secret Life of Walter Mitty           91000000    $58,236,838
# 7      A Walk Among the Tombstones           28000000    $26,017,685
#
#    worldwide_gross  worldwide_profit
# 0            73706       -44926294.0
# 1          1165996          965996.0
# 3          9313302       -15686698.0
# 6        187861183        96861183.0
# 7         62108587        34108587.0

# %%
df_movie_duplicate_dropped.shape
# Out:
# (2126, 9)

# %%
df_movie_duplicate_dropped['Profit'] = df_movie_duplicate_dropped['worldwide_gross'] - df_movie_duplicate_dropped['production_budget']
df_movie_duplicate_dropped[['release_date', 'worldwide_gross', 'production_budget', 'Profit']]
# Out:
# C:\Users\AnnieLiu\AppData\Local\Temp/ipykernel_98556/3306856487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movie_duplicate_dropped['Profit'] = df_movie_duplicate_dropped['worldwide_gross'] - df_movie_duplicate_dropped['production_budget']
#       release_date  worldwide_gross  production_budget    Profit
# 0     Dec 31, 2012            73706           45000000 -44926294
# 1     Jun 19, 2015          1165996             200000    965996
# 3     Mar 22, 2013          9313302           25000000 -15686698
# 6     Dec 25, 2013        187861183           91000000  96861183
# 7     Sep 19, 2014         62108587           28000000  34108587
# ...            ...              ...                ...       ...
# 2870  Dec 29, 1995          4199334            9200000  -5000666
# 2871  Oct 24, 2008           655538             400000    255538
# 2872   Feb 6, 2009         49678401           38000000  11678401
# 2873  Mar 29, 2019         18107621            6000000  12107621
# 2874  Jan 14, 2000           195043              25000    170043
#
# [2126 rows x 4 columns]

# %%
df_movie_duplicate_dropped['release_month'] = pd.DatetimeIndex(df_movie_duplicate_dropped['release_date']).month
# Out:
# C:\Users\AnnieLiu\AppData\Local\Temp/ipykernel_98556/4221637452.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movie_duplicate_dropped['release_month'] = pd.DatetimeIndex(df_movie_duplicate_dropped['release_date']).month

# %%
df_dup_budgets_date = df_movie_duplicate_dropped[df_movie_duplicate_dropped.duplicated()]

# %%
df_dup_budgets_date
# Out:
# Empty DataFrame
# Columns: [genres, averagerating, numvotes, release_date, movie, production_budget, domestic_gross, worldwide_gross, worldwide_profit, Profit, release_month]
# Index: []

# %%
df_movie_duplicate_dropped.head()
# Out:
#                     genres  averagerating  numvotes  release_date  \
# 0  Action,Animation,Comedy            1.9      8248  Dec 31, 2012
# 1                    Drama            7.5        24  Jun 19, 2015
# 3  Adventure,Drama,Romance            6.1     37886  Mar 22, 2013
# 6   Adventure,Comedy,Drama            7.3    275300  Dec 25, 2013
# 7       Action,Crime,Drama            6.5    105116  Sep 19, 2014
#
#                              movie  production_budget domestic_gross  \
# 0                       Foodfight!           45000000             $0
# 1                    The Overnight             200000     $1,109,808
# 3                      On the Road           25000000       $720,828
# 6  The Secret Life of Walter Mitty           91000000    $58,236,838
# 7      A Walk Among the Tombstones           28000000    $26,017,685
#
#    worldwide_gross  worldwide_profit    Profit  release_month
# 0            73706       -44926294.0 -44926294             12
# 1          1165996          965996.0    965996              6
# 3          9313302       -15686698.0 -15686698              3
# 6        187861183        96861183.0  96861183             12
# 7         62108587        34108587.0  34108587              9

# %%
df_movie_duplicate_dropped = df_movie_duplicate_dropped.drop(['worldwide_profit'], axis=1)
df_movie_duplicate_dropped
# Out:
#                        genres  averagerating  numvotes  release_date  \
# 0     Action,Animation,Comedy            1.9      8248  Dec 31, 2012
# 1                       Drama            7.5        24  Jun 19, 2015
# 3     Adventure,Drama,Romance            6.1     37886  Mar 22, 2013
# 6      Adventure,Comedy,Drama            7.3    275300  Dec 25, 2013
# 7          Action,Crime,Drama            6.5    105116  Sep 19, 2014
# ...                       ...            ...       ...           ...
# 2870                    Drama            9.1        28  Dec 29, 1995
# 2871              Documentary            7.3         7  Oct 24, 2008
# 2872              Documentary            7.3        33   Feb 6, 2009
# 2873          Biography,Drama            6.3      5945  Mar 29, 2019
# 2874                 Thriller            6.0         6  Jan 14, 2000
#
#                                 movie  production_budget domestic_gross  \
# 0                          Foodfight!           45000000             $0
# 1                       The Overnight             200000     $1,109,808
# 3                         On the Road           25000000       $720,828
# 6     The Secret Life of Walter Mitty           91000000    $58,236,838
# 7         A Walk Among the Tombstones           28000000    $26,017,685
# ...                               ...                ...            ...
# 2870                      Richard III            9200000     $2,684,904
# 2871                           Heroes             400000       $655,538
# 2872                             Push           38000000    $31,811,527
# 2873                        Unplanned            6000000    $18,107,621
# 2874                    The Terrorist              25000       $195,043
#
#       worldwide_gross    Profit  release_month
# 0               73706 -44926294             12
# 1             1165996    965996              6
# 3             9313302 -15686698              3
# 6           187861183  96861183             12
# 7            62108587  34108587              9
# ...               ...       ...            ...
# 2870          4199334  -5000666             12
# 2871           655538    255538             10
# 2872         49678401  11678401              2
# 2873         18107621  12107621              3
# 2874           195043    170043              1
#
# [2126 rows x 10 columns]

# %%
df_movie_duplicate_dropped['release_date'].min()
# Out:
# 'Apr 1, 2010'

# %%
df_movie_duplicate_dropped.shape
# Out:
# (2126, 10)

# %%
df_movie_duplicate_dropped.groupby('release_month').mean()
# Out:
#                averagerating       numvotes  production_budget  \
# release_month
# 1                   5.982963   47666.992593       2.640623e+07
# 2                   6.165132   75535.151316       3.471961e+07
# 3                   6.140110   79390.868132       4.302652e+07
# 4                   6.260112   58971.269663       3.005708e+07
# 5                   6.258451  121914.077465       5.971279e+07
# 6                   6.322892   99163.277108       5.467102e+07
# 7                   6.268263  105282.724551       4.518946e+07
# 8                   6.116949   66833.666667       2.834536e+07
# 9                   6.295628   69529.945355       2.469013e+07
# 10                  6.256522   78599.908213       2.359413e+07
# 11                  6.636313  116944.335196       4.777460e+07
# 12                  6.077907   72193.426357       3.455381e+07
#
#                worldwide_gross        Profit
# release_month
# 1                 6.398189e+07  3.757566e+07
# 2                 9.977082e+07  6.505122e+07
# 3                 1.172696e+08  7.424311e+07
# 4                 9.439885e+07  6.434177e+07
# 5                 1.835001e+08  1.237873e+08
# 6                 1.910767e+08  1.364057e+08
# 7                 1.548137e+08  1.096243e+08
# 8                 7.351027e+07  4.516491e+07
# 9                 5.994329e+07  3.525316e+07
# 10                6.461829e+07  4.102415e+07
# 11                1.546475e+08  1.068729e+08
# 12                1.179025e+08  8.334867e+07

# %%
#create a boxplot using release month and profit
x = df_movie_duplicate_dropped['release_month']
y = df_movie_duplicate_dropped['Profit']
f, ax = plt.subplots(figsize=(14,12))
sns.set_style('darkgrid')
sns.set_context('talk') 
sns.boxplot(x, y, palette='Set3', showfliers=False)
plt.title('Movies - Time of Year and profitability ')
plt.ylabel('Profit')
plt.xlabel('Month of Movie Release') 
plt.show()
# Out:
# C:\Users\AnnieLiu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ####  <span style="color:green">Boxplot suggests higher profitability during mid year and November. Therefore Microsoft should consider releasing movies during these periods</span>.

# %% [markdown]
# # Budget by Ave. Rating

# %%
df_av_ratings = df_movie_duplicate_dropped[['averagerating', 'production_budget']]
df_av_ratings
# Out:
#       averagerating  production_budget
# 0               1.9           45000000
# 1               7.5             200000
# 3               6.1           25000000
# 6               7.3           91000000
# 7               6.5           28000000
# ...             ...                ...
# 2870            9.1            9200000
# 2871            7.3             400000
# 2872            7.3           38000000
# 2873            6.3            6000000
# 2874            6.0              25000
#
# [2126 rows x 2 columns]

# %%
df_av_ratings.sort_values(by=['averagerating'])
# Out:
#       averagerating  production_budget
# 1129            1.6           13000000
# 0               1.9           45000000
# 2189            2.1           30000000
# 1761            2.2            1000000
# 2144            2.3            3000000
# ...             ...                ...
# 1804            9.0           20000000
# 1306            9.0           45000000
# 1921            9.0           11000000
# 2870            9.1            9200000
# 684             9.2            3000000
#
# [2126 rows x 2 columns]

# %%
x = 'averagerating'
y = 'production_budget'

subset_data = df_av_ratings.sample(2126)[[x,y]]
subset_data.sort_values(['averagerating'], ascending=True, inplace=True)
subset_data.dropna(inplace=True)

subset_data.plot(x=x, y=y, kind='scatter', title='Budget vs Rating')
# Out:
# <AxesSubplot:title={'center':'Budget vs Rating'}, xlabel='averagerating', ylabel='production_budget'>

# %%
df_rating_mean = df_av_ratings.groupby('averagerating').mean()
df_rating_mean
# Out:
#                production_budget
# averagerating
# 1.6                 1.300000e+07
# 1.9                 4.500000e+07
# 2.1                 3.000000e+07
# 2.2                 1.000000e+06
# 2.3                 3.000000e+06
# ...                          ...
# 8.8                 5.316667e+07
# 8.9                 1.500000e+07
# 9.0                 2.533333e+07
# 9.1                 9.200000e+06
# 9.2                 3.000000e+06
#
# [74 rows x 1 columns]

# %%
df_rating_mean['averagerating_rounded'] = df_rating_mean.index.astype(int)

# %%
df_rating_mean.dtypes
# Out:
# production_budget        float64
# averagerating_rounded      int64
# dtype: object

# %%
df_rating_mean
# Out:
#                production_budget  averagerating_rounded
# averagerating
# 1.6                 1.300000e+07                      1
# 1.9                 4.500000e+07                      1
# 2.1                 3.000000e+07                      2
# 2.2                 1.000000e+06                      2
# 2.3                 3.000000e+06                      2
# ...                          ...                    ...
# 8.8                 5.316667e+07                      8
# 8.9                 1.500000e+07                      8
# 9.0                 2.533333e+07                      9
# 9.1                 9.200000e+06                      9
# 9.2                 3.000000e+06                      9
#
# [74 rows x 2 columns]

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 8,6
plt.axvline(0, c=(.5, .5, .5), ls='--')
plt.axhline(0, c=(.5, .5, .5), ls='--')
plt.style.use('seaborn')
plt.scatter(df_rating_mean. averagerating_rounded, df_rating_mean.production_budget, c=df_rating_mean.production_budget, cmap='Spectral', edgecolor='k')


plt.xlabel("averagerating_rounded")
plt.ylabel("production_budget")
plt.title('Budget vs. Ratings')
# Out:
# Text(0.5, 1.0, 'Budget vs. Ratings')

# %%
sns.factorplot(y="production_budget", col="averagerating_rounded", col_wrap=9, data=df_rating_mean, kind="box", height=6, aspect=0.5);
# Out:
# C:\Users\AnnieLiu\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ####  <span style="color:green">Movies with higher budgets generally have higher average ratings</span>.
